# %% [markdown]
# <a href="https://colab.research.google.com/github/Anshul8951/Python2/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=5
print (a)
# Out:
# 5

# %% [markdown]
# dscsdc
